# %%
import sys
import os

import numpy as np
import matplotlib.pyplot as plt

sys.path.append(os.path.abspath(os.path.join("..", "src")))
import features_calculator
import features_aggregator

# %%
arr = np.load('image.npy')

plt.imshow(arr)
plt.show()

# %%
raw_features = features_calculator.calculate_all_features(arr)
summarized_features = features_aggregator.get_all_features(raw_features)

# %%
print(summarized_features)
# Out:
# {'pos_largest_byarea_area': np.float64(25480.0), 'pos_largest_byarea_perimeter': np.float64(1937.3677118368964), 'pos_largest_byarea_major_axis_length': 348.45557107873344, 'pos_largest_byarea_minor_axis_length': 221.37941843026607, 'pos_largest_byarea_aspect_ratio': 1.5740197239179938, 'pos_largest_byarea_circularitie': np.float64(0.08530709886500018), 'pos_largest_byarea_nearest_neighbor_distance': np.float64(109.43308301182859), 'pos_largest_byarea_incircle_rad': np.float64(61.204574992397426), 'pos_largest_byarea_excircle_rad': 180.3123321533203, 'pos_smallest_byarea_area': np.float64(1.0), 'pos_smallest_byarea_perimeter': np.float64(0.0), 'pos_smallest_byarea_major_axis_length': 0.0, 'pos_smallest_byarea_minor_axis_length': 0.0, 'pos_smallest_byarea_aspect_ratio': nan, 'pos_smallest_byarea_circularitie': nan, 'pos_smallest_byarea_nearest_neighbor_distance': np.float64(96.41716056873985), 'pos_smallest_byarea_incircle_rad': np.float64(1.0), 'pos_smallest_byarea_excircle_rad': 9.9
# ...
